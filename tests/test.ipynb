# %%
import numpy as np
import photonforge as pf
import siepic_forge as siepic
import luxtelligence_lnoi400_forge as lxt

siepic_tech = siepic.ebeam()
basic_tech = pf.basic_technology()
lxt_tech = lxt.lnoi400()

pf.config.default_technology = lxt_tech

# %%
siepic.component_names
# Out:
# {'ANT_MMI_1x2_te1550_3dB_BB',
#  'GC_SiN_TE_1310_8degOxide_BB',
#  'GC_SiN_TE_1550_8degOxide_BB',
#  'GC_TE_1310_8degOxide_BB',
#  'GC_TE_1550_8degOxide_BB',
#  'GC_TM_1310_8degOxide_BB',
#  'GC_TM_1550_8degOxide_BB',
#  'crossing_horizontal',
#  'crossing_manhattan',
#  'ebeam_BondPad',
#  'ebeam_DC_2-1_te895',
#  'ebeam_DC_te895',
#  'ebeam_MMI_2x2_5050_te1310',
#  'ebeam_Polarizer_TM_1550_UQAM',
#  'ebeam_YBranch_895',
#  'ebeam_YBranch_te1310',
#  'ebeam_adiabatic_te1550',
#  'ebeam_adiabatic_tm1550',
#  'ebeam_bdc_te1550',
#  'ebeam_crossing4',
#  'ebeam_gc_te1550',
#  'ebeam_gc_te895',
#  'ebeam_gc_tm1550',
#  'ebeam_routing_taper_te1550_w=500nm_to_w=3000nm_L=20um',
#  'ebeam_routing_taper_te1550_w=500nm_to_w=3000nm_L=40um',
#  'ebeam_splitter_swg_assist_te1310',
#  'ebeam_splitter_swg_assist_te1550',
#  'ebeam_terminator_SiN_1550',
#  'ebeam_terminator_SiN_te895',
#  'ebeam_terminator_te1310',
#  'ebeam_terminator_te1550',
#  'ebeam_terminator_tm1550',
#  'ebeam_y_1550',
#  'ebeam_y_adiabatic',
#  'ebeam_y_adiabatic_500pin',
#  'taper_SiN_750_3000',
#  'taper_si_simm_1310',
#  'taper_si_simm_1550'}

# %%
lxt.component.u_bend_racetrack()
# Out:
# Component(name="UBEND_RACETRACK_IMNG2YPRKDIF5BGDI5LMZC6IFH2SL4LSKCM4WSNKFZI7LVA2HMFA", technology=Technology(name="LNOI400", version="1.2.6", layers={"CHIP_EXCLUSION_ZONE": LayerSpec(layer=(6, 1), description="Final chip boundaries", color="#00fe9c18", pattern="/"), "LN_RIDGE": LayerSpec(layer=(2, 0), description="LN etch (ridge)", color="#7d57de18", pattern="//"), "LN_SLAB": LayerSpec(layer=(3, 0), description="LN etch (full)", color="#00008018", pattern="\"), "TL": LayerSpec(layer=(21, 0), description="Metal transmission lines", color="#eadb0718", pattern="\"), "SLAB_NEGATIVE": LayerSpec(layer=(3, 1), description="Slab etch negative", color="#6750bf18", pattern="\"), "LABELS": LayerSpec(layer=(4, 0), description="Labels (LN etch)", color="#5179b518", pattern="/"), "ALIGN": LayerSpec(layer=(31, 0), description="Alignment markers (LN etch)", color="#ba29c218", pattern="/"), "CHIP_CONTOUR": LayerSpec(layer=(6, 0), description="Usable floorplan area", color="#ffc6b818", pattern="\"), "HT": LayerSpec(layer=(21, 1), description="Metal heaters", color="#f0b90518", pattern="."), "DOC": LayerSpec(layer=(201, 0), description="Labels for GDS layout (not fabricated)", color="#80a8ff18", pattern=".")}, extrusion_specs=[ExtrusionSpec(mask_spec=MaskSpec(operand0=[], operand1=[], operation='+'), medium={"optical": AnisotropicMedium(zz={'attrs': {}, 'name': 'LiNbO3_Zelmon1997', 'frequency_range': (59958491600000.0, 749481145000000.0), 'allow_gain': False, 'nonlinear_spec': None, 'modulation_spec': None, 'viz_spec': None, 'heat_spec': None, 'type': 'PoleResidue', 'eps_inf': 1.0, 'poles': ((1.4182450644861764e+16j, (-0-1.895768177698672e+16j)), (7745686426535269j, (-0-4759724309105923j)), (86464275012302.47j, (-0-545330182502591.7j)))}, xx={'attrs': {}, 'name': 'LiNbO3_Zelmon1997', 'frequency_range': (59958491600000.0, 749481145000000.0), 'allow_gain': False, 'nonlinear_spec': None, 'modulation_spec': None, 'viz_spec': None, 'heat_spec': None, 'type': 'PoleResidue', 'eps_inf': 1.0, 'poles': ((1.4182450644861764e+16j, (-0-1.895768177698672e+16j)), (7745686426535269j, (-0-4759724309105923j)), (86464275012302.47j, (-0-545330182502591.7j)))}, yy={'attrs': {}, 'name': 'LiNbO3_Zelmon1997', 'frequency_range': (59958491600000.0, 749481145000000.0), 'allow_gain': False, 'nonlinear_spec': None, 'modulation_spec': None, 'viz_spec': None, 'heat_spec': None, 'type': 'PoleResidue', 'eps_inf': 1.0, 'poles': ((1.3165630127713252e+16j, (-0-1.961942201631829e+16j)), (7299001563858286j, (-0-2182766417671820.2j)), (92344737457068.7j, (-0-413441241305915.1j)))}), "electrical": AnisotropicMedium(zz={'attrs': {}, 'name': None, 'frequency_range': None, 'allow_gain': False, 'nonlinear_spec': None, 'modulation_spec': None, 'viz_spec': None, 'heat_spec': None, 'type': 'Medium', 'permittivity': 44.0, 'conductivity': 0.0}, xx={'attrs': {}, 'name': None, 'frequency_range': None, 'allow_gain': False, 'nonlinear_spec': None, 'modulation_spec': None, 'viz_spec': None, 'heat_spec': None, 'type': 'Medium', 'permittivity': 44.0, 'conductivity': 0.0}, yy={'attrs': {}, 'name': None, 'frequency_range': None, 'allow_gain': False, 'nonlinear_spec': None, 'modulation_spec': None, 'viz_spec': None, 'heat_spec': None, 'type': 'Medium', 'permittivity': 27.9, 'conductivity': 0.0})}, limits=(0, 0.2), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec(operand0=[MaskSpec((2, 0)), MaskSpec((4, 0)), MaskSpec((31, 0))], operand1=[], operation='+'), medium={"optical": AnisotropicMedium(zz={'attrs': {}, 'name': 'LiNbO3_Zelmon1997', 'frequency_range': (59958491600000.0, 749481145000000.0), 'allow_gain': False, 'nonlinear_spec': None, 'modulation_spec': None, 'viz_spec': None, 'heat_spec': None, 'type': 'PoleResidue', 'eps_inf': 1.0, 'poles': ((1.4182450644861764e+16j, (-0-1.895768177698672e+16j)), (7745686426535269j, (-0-4759724309105923j)), (86464275012302.47j, (-0-545330182502591.7j)))}, xx={'attrs': {}, 'name': 'LiNbO3_Zelmon1997', 'frequency_range': (59958491600000.0, 7494811 ...

# %%
lxt.component_names
# Out:
# ('chip_frame',
#  'cpw_probe_pad_linear',
#  'dir_coupl',
#  'double_linear_inverse_taper',
#  'eo_phase_shifter',
#  'heated_straight_waveguide',
#  'heater_pad',
#  'heater_straight',
#  'l_turn_bend',
#  'mmi1x2',
#  'mmi2x2',
#  'mz_modulator_unbalanced',
#  's_bend_var_width',
#  's_bend_vert',
#  'u_bend_racetrack',
#  'u_turn_bend')
